# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## ConceptNet

# %%
colnames = ["relation", "subject", "object", "license", "source", "process", "weight"]
df_co = pd.read_csv("../../data/conceptnet/conceptnet-assertions-5.7.0.csv", warn_bad_lines=False, error_bad_lines=False, names=colnames, header=None, low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1048239/4100527629.py in <module>
#       1 colnames = ["relation", "subject", "object", "license", "source", "process", "weight"]
# ----> 2 df_co = pd.read_csv("../../data/conceptnet/conceptnet-assertions-5.7.0.csv", warn_bad_lines=False, error_bad_lines=False, names=colnames, header=None, low_memory=False)
#
# ~/anaconda3/envs/kbvqa/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/envs/kbvqa/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# ~/anaconda3/envs/kbvqa/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~/anaconda3/envs/kbvqa/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/anaconda3/envs/kbvqa/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570
#     571
# --> 572 def is_categorical_dtype(arr_or_dtype):
#     573     """
#     574     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
df_co[df_co["relation"] == "/a/[/r/RelatedTo/"]
# Out:
#                    relation               subject  \
# 17716847  /a/[/r/RelatedTo/              /c/aa/a/
# 17716848  /a/[/r/RelatedTo/            /c/aa/a/a/
# 17716849  /a/[/r/RelatedTo/       /c/aa/a_saku/r/
# 17716850  /a/[/r/RelatedTo/         /c/aa/abal/n/
# 17716851  /a/[/r/RelatedTo/         /c/aa/abar/n/
# 17716852  /a/[/r/RelatedTo/      /c/aa/abatasa/n/
# 17716853  /a/[/r/RelatedTo/         /c/aa/abba/n/
# 17716854  /a/[/r/RelatedTo/         /c/aa/abba/n/
# 17716855  /a/[/r/RelatedTo/         /c/aa/abba/n/
# 17716856  /a/[/r/RelatedTo/         /c/aa/abba/n/
# 17716857  /a/[/r/RelatedTo/    /c/aa/abba_bada/n/
# 17716858  /a/[/r/RelatedTo/    /c/aa/abba_bada/n/
# 17716859  /a/[/r/RelatedTo/    /c/aa/abbah_ina/n/
# 17716860  /a/[/r/RelatedTo/       /c/aa/abbire/v/
# 17716861  /a/[/r/RelatedTo/          /c/aa/abe/v/
# 17716862  /a/[/r/RelatedTo/         /c/aa/able/v/
# 17716863  /a/[/r/RelatedTo/       /c/aa/aboyya/n/
# 17716864  /a/[/r/RelatedTo/       /c/aa/absuma/n/
# 17716865  /a/[/r/RelatedTo/       /c/aa/absuma/n/
# 17716866  /a/[/r/RelatedTo/          /c/aa/abu/n/
# 17716867  /a/[/r/RelatedTo/          /c/aa/abu/n/
# 17716868  /a/[/r/RelatedTo/        /c/aa/abuke/v/
# 17716869  /a/[/r/RelatedTo/         /c/aa/abur/n/
# 17716870  /a/[/r/RelatedTo/        /c/aa/aburo/n/
# 17716871  /a/[/r/RelatedTo/        /c/aa/aburo/n/
# 17716872  /a/[/r/RelatedTo/        /c/aa/ab’ha/n/
# 17716873  /a/[/r/RelatedTo/          /c/aa/ada/n/
# 17716874  /a/[/r/RelatedTo/        /c/aa/adaga/n/
# 17716875  /a/[/r/RelatedTo/         /c/aa/adal/a/
# 17716876  /a/[/r/RelatedTo/      /c/aa/adarras/a/
# ...                     ...                   ...
# 26847128  /a/[/r/RelatedTo/     /c/zza/ıspenağ/n/
# 26847129  /a/[/r/RelatedTo/         /c/zza/ıstan/
# 26847130  /a/[/r/RelatedTo/         /c/zza/ıstan/
# 26847131  /a/[/r/RelatedTo/       /c/zza/şehid/n/
# 26847132  /a/[/r/RelatedTo/       /c/zza/şehîd/n/
# 26847133  /a/[/r/RelatedTo/         /c/zza/şek/n/
# 26847134  /a/[/r/RelatedTo/       /c/zza/şeker/n/
# 26847135  /a/[/r/RelatedTo/        /c/zza/şeme/n/
# 26847136  /a/[/r/RelatedTo/        /c/zza/şerm/n/
# 26847137  /a/[/r/RelatedTo/   /c/zza/şermayene/v/
# 26847138  /a/[/r/RelatedTo/       /c/zza/şermı/n/
# 26847139  /a/[/r/RelatedTo/         /c/zza/şew/n/
# 26847140  /a/[/r/RelatedTo/       /c/zza/şewra/r/
# 26847141  /a/[/r/RelatedTo/    /c/zza/şewşewık/n/
# 26847142  /a/[/r/RelatedTo/    /c/zza/şeytanok/n/
# 26847143  /a/[/r/RelatedTo/           /c/zza/şeş/
# 26847144  /a/[/r/RelatedTo/      /c/zza/şimşêr/n/
# 26847145  /a/[/r/RelatedTo/         /c/zza/şit/n/
# 26847146  /a/[/r/RelatedTo/      /c/zza/şiwone/n/
# 26847147  /a/[/r/RelatedTo/         /c/zza/şon/n/
# 26847148  /a/[/r/RelatedTo/        /c/zza/şone/n/
# 26847149  /a/[/r/RelatedTo/       /c/zza/şorve/n/
# 26847150  /a/[/r/RelatedTo/      /c/zza/şutene/v/
# 26847151  /a/[/r/RelatedTo/        /c/zza/şuşe/n/
# 26847152  /a/[/r/RelatedTo/         /c/zza/şêr/n/
# 26847153  /a/[/r/RelatedTo/       /c/zza/şîrin/a/
# 26847154  /a/[/r/RelatedTo/    /c/zza/şınasiye/n/
# 26847155  /a/[/r/RelatedTo/  /c/zza/şınasnayış/n/
# 26847156  /a/[/r/RelatedTo/  /c/zza/şınasnayış/n/
# 26847157  /a/[/r/RelatedTo/          /c/zza/šest/
#
#                                                      object  \
# 17716847  /c/en/this/]\t/r/RelatedTo\t/c/aa/a\t/c/en/thi...
# 17716848  /c/fr/ce/]\t/r/RelatedTo\t/c/aa/a/a\t/c/fr/ce\...
# 17716849  /c/fr/aujourd’hui/]\t/r/RelatedTo\t/c/aa/a_sak...
# 17716850  /c/fr/sang/]\t/r/RelatedTo\t/c/aa/abal/n\t/c/f...
# 17716851  /c/fr/sècheresse/]\t/r/RelatedTo\t/c/aa/abar/n...
# 17716852  /c/fr/alphabet/]\t/r/RelatedTo\t/c/aa/abatasa/...
# 17716853  /c/fr/chef_de_famille/]\t/r/RelatedTo\t/c/aa/a...
# 17716854  /c/fr/géniteur/]\t/r/RelatedTo\t/c/aa/abba/n\t...
# 17716855  /c/fr/président/]\t/r/RelatedTo\t/c/aa/abba/n\...
# 17716856  /c/fr/père/]\t/r/RelatedTo\t/c/aa/abba/n\t/c/f...
# 17716857  /c/fr/demi_frère/]\t/r/RelatedTo\t/c/aa/abba_b...
# 17716858  /c/fr/demi_sœur/]\t/r/RelatedTo\t/c/aa/abba_ba...
# 17716859  /c/fr/grand_mère/]\t/r/RelatedTo\t/c/aa/abbah_...
# 17716860  /c/fr/attraper/]\t/r/RelatedTo\t/c/aa/abbire/v...
# 17716861  /c/fr/faire/]\t/r/RelatedTo\t/c/aa/abe/v\t/c/f...
# 17716862  /c/fr/voir/]\t/r/RelatedTo\t/c/aa/able/v\t/c/f...
# 17716863  /c/fr/grand_mère/]\t/r/RelatedTo\t/c/aa/aboyya...
# 17716864  /c/fr/cousin/]\t/r/RelatedTo\t/c/aa/absuma/n\t...
# 17716865  /c/fr/cousine/]\t/r/RelatedTo\t/c/aa/absuma/n\...
# 17716866  /c/fr/ancêtre/]\t/r/RelatedTo\t/c/aa/abu/n\t/c...
# 17716867  /c/fr/oncle_maternel/]\t/r/RelatedTo\t/c/aa/ab...
# 17716868  /c/fr/naître/]\t/r/RelatedTo\t/c/aa/abuke/v\t/...
# 17716869  /c/fr/taureau/]\t/r/RelatedTo\t/c/aa/abur/n\t/...
# 17716870  /c/fr/hyène/]\t/r/RelatedTo\t/c/aa/aburo/n\t/c...
# 17716871  /c/fr/veuf/]\t/r/RelatedTo\t/c/aa/aburo/n\t/c/...
# 17716872  /c/fr/source/]\t/r/RelatedTo\t/c/aa/ab’ha/n\t/...
# 17716873  /c/fr/tradition/]\t/r/RelatedTo\t/c/aa/ada/n\t...
# 17716874  /c/fr/marché/]\t/r/RelatedTo\t/c/aa/adaga/n\t/...
# 17716875  /c/fr/beau/]\t/r/RelatedTo\t/c/aa/adal/a\t/c/f...
# 17716876  /c/fr/facile/]\t/r/RelatedTo\t/c/aa/adarras/a\...
# ...                                                     ...
# 26847128  /c/en/spinach/]\t/r/RelatedTo\t/c/zza/ıspenağ/...
# 26847129  /c/en/land/]\t/r/RelatedTo\t/c/zza/ıstan\t/c/e...
# 26847130  /c/en/stan/]\t/r/RelatedTo\t/c/zza/ıstan\t/c/e...
# 26847131  /c/en/martyr/]\t/r/RelatedTo\t/c/zza/şehid/n\t...
# 26847132  /c/en/martyr/]\t/r/RelatedTo\t/c/zza/şehîd/n\t...
# 26847133  /c/en/doubt/]\t/r/RelatedTo\t/c/zza/şek/n\t/c/...
# 26847134  /c/en/sugar/]\t/r/RelatedTo\t/c/zza/şeker/n\t/...
# 26847135  /c/fr/samedi/]\t/r/RelatedTo\t/c/zza/şeme/n\t/...
# 26847136  /c/en/shame/]\t/r/RelatedTo\t/c/zza/şerm/n\t/c...
# 26847137  /c/en/be_ashamed/]\t/r/RelatedTo\t/c/zza/şerma...
# 26847138  /c/en/shame/]\t/r/RelatedTo\t/c/zza/şermı/n\t/...
# 26847139  /c/en/night/]\t/r/RelatedTo\t/c/zza/şew/n\t/c/...
# 26847140  /c/en/tomorrow/]\t/r/RelatedTo\t/c/zza/şewra/r...
# 26847141  /c/en/bat/]\t/r/RelatedTo\t/c/zza/şewşewık/n\t...
# 26847142  /c/en/snail/]\t/r/RelatedTo\t/c/zza/şeytanok/n...
# 26847143  /c/en/six/]\t/r/RelatedTo\t/c/zza/şeş\t/c/en/s...
# 26847144  /c/en/sword/]\t/r/RelatedTo\t/c/zza/şimşêr/n\t...
# 26847145  /c/en/milk/]\t/r/RelatedTo\t/c/zza/şit/n\t/c/e...
# 26847146  /c/en/shepherd/]\t/r/RelatedTo\t/c/zza/şiwone/...
# 26847147  /c/en/evening/]\t/r/RelatedTo\t/c/zza/şon/n\t/...
# 26847148  /c/en/comb/]\t/r/RelatedTo\t/c/zza/şone/n\t/c/...
# 26847149  /c/en/soup/]\t/r/RelatedTo\t/c/zza/şorve/n\t/c...
# 26847150  /c/en/wash/]\t/r/RelatedTo\t/c/zza/şutene/v\t/...
# 26847151  /c/en/glass/]\t/r/RelatedTo\t/c/zza/şuşe/n\t/c...
# 26847152  /c/en/lion/]\t/r/RelatedTo\t/c/zza/şêr/n\t/c/e...
# 26847153  /c/en/sweet/]\t/r/RelatedTo\t/c/zza/şîrin/a\t/...
# 26847154  /c/en/science/]\t/r/RelatedTo\t/c/zza/şınasiye...
# 26847155  /c/en/identification/]\t/r/RelatedTo\t/c/zza/ş...
# 26847156  /c/en/recognition/]\t/r/RelatedTo\t/c/zza/şına...
# 26847157  /c/en/six/]\t/r/RelatedTo\t/c/zza/šest\t/c/en/...
#
#                              license  \
# 17716847   "license": "cc:by-sa/4.0"
# 17716848   "license": "cc:by-sa/4.0"
# 17716849   "license": "cc:by-sa/4.0"
# 17716850   "license": "cc:by-sa/4.0"
# 17716851   "license": "cc:by-sa/4.0"
# 17716852   "license": "cc:by-sa/4.0"
# 17716853   "license": "cc:by-sa/4.0"
# 17716854   "license": "cc:by-sa/4.0"
# 17716855   "license": "cc:by-sa/4.0"
# 17716856   "license": "cc:by-sa/4.0"
# 17716857   "license": "cc:by-sa/4.0"
# 17716858   "license": "cc:by-sa/4.0"
# 17716859   "license": "cc:by-sa/4.0"
# 17716860   "license": "cc:by-sa/4.0"
# 17716861   "license": "cc:by-sa/4.0"
# 17716862   "license": "cc:by-sa/4.0"
# 17716863   "license": "cc:by-sa/4.0"
# 17716864   "license": "cc:by-sa/4.0"
# 17716865   "license": "cc:by-sa/4.0"
# 17716866   "license": "cc:by-sa/4.0"
# 17716867   "license": "cc:by-sa/4.0"
# 17716868   "license": "cc:by-sa/4.0"
# 17716869   "license": "cc:by-sa/4.0"
# 17716870   "license": "cc:by-sa/4.0"
# 17716871   "license": "cc:by-sa/4.0"
# 17716872   "license": "cc:by-sa/4.0"
# 17716873   "license": "cc:by-sa/4.0"
# 17716874   "license": "cc:by-sa/4.0"
# 17716875   "license": "cc:by-sa/4.0"
# 17716876   "license": "cc:by-sa/4.0"
# ...                              ...
# 26847128   "license": "cc:by-sa/4.0"
# 26847129   "license": "cc:by-sa/4.0"
# 26847130   "license": "cc:by-sa/4.0"
# 26847131   "license": "cc:by-sa/4.0"
# 26847132   "license": "cc:by-sa/4.0"
# 26847133   "license": "cc:by-sa/4.0"
# 26847134   "license": "cc:by-sa/4.0"
# 26847135   "license": "cc:by-sa/4.0"
# 26847136   "license": "cc:by-sa/4.0"
# 26847137   "license": "cc:by-sa/4.0"
# 26847138   "license": "cc:by-sa/4.0"
# 26847139   "license": "cc:by-sa/4.0"
# 26847140   "license": "cc:by-sa/4.0"
# 26847141   "license": "cc:by-sa/4.0"
# 26847142   "license": "cc:by-sa/4.0"
# 26847143   "license": "cc:by-sa/4.0"
# 26847144   "license": "cc:by-sa/4.0"
# 26847145   "license": "cc:by-sa/4.0"
# 26847146   "license": "cc:by-sa/4.0"
# 26847147   "license": "cc:by-sa/4.0"
# 26847148   "license": "cc:by-sa/4.0"
# 26847149   "license": "cc:by-sa/4.0"
# 26847150   "license": "cc:by-sa/4.0"
# 26847151   "license": "cc:by-sa/4.0"
# 26847152   "license": "cc:by-sa/4.0"
# 26847153   "license": "cc:by-sa/4.0"
# 26847154   "license": "cc:by-sa/4.0"
# 26847155   "license": "cc:by-sa/4.0"
# 26847156   "license": "cc:by-sa/4.0"
# 26847157   "license": "cc:by-sa/4.0"
#
#                                                      source  \
# 17716847   "sources": [{"contributor": "/s/resource/wikt...
# 17716848   "sources": [{"contributor": "/s/resource/wikt...
# 17716849   "sources": [{"contributor": "/s/resource/wikt...
# 17716850   "sources": [{"contributor": "/s/resource/wikt...
# 17716851   "sources": [{"contributor": "/s/resource/wikt...
# 17716852   "sources": [{"contributor": "/s/resource/wikt...
# 17716853   "sources": [{"contributor": "/s/resource/wikt...
# 17716854   "sources": [{"contributor": "/s/resource/wikt...
# 17716855   "sources": [{"contributor": "/s/resource/wikt...
# 17716856   "sources": [{"contributor": "/s/resource/wikt...
# 17716857   "sources": [{"contributor": "/s/resource/wikt...
# 17716858   "sources": [{"contributor": "/s/resource/wikt...
# 17716859   "sources": [{"contributor": "/s/resource/wikt...
# 17716860   "sources": [{"contributor": "/s/resource/wikt...
# 17716861   "sources": [{"contributor": "/s/resource/wikt...
# 17716862   "sources": [{"contributor": "/s/resource/wikt...
# 17716863   "sources": [{"contributor": "/s/resource/wikt...
# 17716864   "sources": [{"contributor": "/s/resource/wikt...
# 17716865   "sources": [{"contributor": "/s/resource/wikt...
# 17716866   "sources": [{"contributor": "/s/resource/wikt...
# 17716867   "sources": [{"contributor": "/s/resource/wikt...
# 17716868   "sources": [{"contributor": "/s/resource/wikt...
# 17716869   "sources": [{"contributor": "/s/resource/wikt...
# 17716870   "sources": [{"contributor": "/s/resource/wikt...
# 17716871   "sources": [{"contributor": "/s/resource/wikt...
# 17716872   "sources": [{"contributor": "/s/resource/wikt...
# 17716873   "sources": [{"contributor": "/s/resource/wikt...
# 17716874   "sources": [{"contributor": "/s/resource/wikt...
# 17716875   "sources": [{"contributor": "/s/resource/wikt...
# 17716876   "sources": [{"contributor": "/s/resource/wikt...
# ...                                                     ...
# 26847128   "sources": [{"contributor": "/s/resource/wikt...
# 26847129   "sources": [{"contributor": "/s/resource/wikt...
# 26847130   "sources": [{"contributor": "/s/resource/wikt...
# 26847131   "sources": [{"contributor": "/s/resource/wikt...
# 26847132   "sources": [{"contributor": "/s/resource/wikt...
# 26847133   "sources": [{"contributor": "/s/resource/wikt...
# 26847134   "sources": [{"contributor": "/s/resource/wikt...
# 26847135   "sources": [{"contributor": "/s/resource/wikt...
# 26847136   "sources": [{"contributor": "/s/resource/wikt...
# 26847137   "sources": [{"contributor": "/s/resource/wikt...
# 26847138   "sources": [{"contributor": "/s/resource/wikt...
# 26847139   "sources": [{"contributor": "/s/resource/wikt...
# 26847140   "sources": [{"contributor": "/s/resource/wikt...
# 26847141   "sources": [{"contributor": "/s/resource/wikt...
# 26847142   "sources": [{"contributor": "/s/resource/wikt...
# 26847143   "sources": [{"contributor": "/s/resource/wikt...
# 26847144   "sources": [{"contributor": "/s/resource/wikt...
# 26847145   "sources": [{"contributor": "/s/resource/wikt...
# 26847146   "sources": [{"contributor": "/s/resource/wikt...
# 26847147   "sources": [{"contributor": "/s/resource/wikt...
# 26847148   "sources": [{"contributor": "/s/resource/wikt...
# 26847149   "sources": [{"contributor": "/s/resource/wikt...
# 26847150   "sources": [{"contributor": "/s/resource/wikt...
# 26847151   "sources": [{"contributor": "/s/resource/wikt...
# 26847152   "sources": [{"contributor": "/s/resource/wikt...
# 26847153   "sources": [{"contributor": "/s/resource/wikt...
# 26847154   "sources": [{"contributor": "/s/resource/wikt...
# 26847155   "sources": [{"contributor": "/s/resource/wikt...
# 26847156   "sources": [{"contributor": "/s/resource/wikt...
# 26847157   "sources": [{"contributor": "/s/resource/wikt...
#
#                                           process           weight
# 17716847   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716848   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716849   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716850   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716851   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716852   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716853   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716854   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716855   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716856   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716857   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716858   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716859   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716860   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716861   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716862   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716863   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716864   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716865   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716866   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716867   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716868   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716869   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716870   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716871   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716872   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716873   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716874   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716875   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 17716876   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# ...                                           ...              ...
# 26847128   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847129   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847130   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847131   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847132   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847133   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847134   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847135   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847136   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847137   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847138   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847139   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847140   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847141   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847142   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847143   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847144   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847145   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847146   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847147   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847148   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847149   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847150   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847151   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847152   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847153   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847154   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847155   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847156   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 26847157   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
#
# [9130311 rows x 7 columns]

# %%
df_co[df_co["subject"] == "/c/en/piano/r/"]
# Out:
#                     relation         subject  \
# 16193396  /a/[/r/HasContext/  /c/en/piano/r/
# 19941017   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941018   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941019   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941020   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941021   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941022   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941023   /a/[/r/RelatedTo/  /c/en/piano/r/
# 19941024   /a/[/r/RelatedTo/  /c/en/piano/r/
#
#                                                      object  \
# 16193396  /c/en/music/]\t/r/HasContext\t/c/en/piano/r\t/...
# 19941017  /c/de/leise/]\t/r/RelatedTo\t/c/en/piano/r\t/c...
# 19941018  /c/en/direction/]\t/r/RelatedTo\t/c/en/piano/r...
# 19941019  /c/en/mezzo_piano/]\t/r/RelatedTo\t/c/en/piano...
# 19941020  /c/en/mp/]\t/r/RelatedTo\t/c/en/piano/r\t/c/en...
# 19941021  /c/en/pianissimo/]\t/r/RelatedTo\t/c/en/piano/...
# 19941022  /c/en/pp/]\t/r/RelatedTo\t/c/en/piano/r\t/c/en...
# 19941023  /c/en/sheet_music/]\t/r/RelatedTo\t/c/en/piano...
# 19941024  /c/en/softly/]\t/r/RelatedTo\t/c/en/piano/r\t/...
#
#                              license  \
# 16193396   "license": "cc:by-sa/4.0"
# 19941017   "license": "cc:by-sa/4.0"
# 19941018   "license": "cc:by-sa/4.0"
# 19941019   "license": "cc:by-sa/4.0"
# 19941020   "license": "cc:by-sa/4.0"
# 19941021   "license": "cc:by-sa/4.0"
# 19941022   "license": "cc:by-sa/4.0"
# 19941023   "license": "cc:by-sa/4.0"
# 19941024   "license": "cc:by-sa/4.0"
#
#                                                      source  \
# 16193396   "sources": [{"contributor": "/s/resource/wikt...
# 19941017   "sources": [{"contributor": "/s/resource/wikt...
# 19941018   "sources": [{"contributor": "/s/resource/wikt...
# 19941019   "sources": [{"contributor": "/s/resource/wikt...
# 19941020   "sources": [{"contributor": "/s/resource/wikt...
# 19941021   "sources": [{"contributor": "/s/resource/wikt...
# 19941022   "sources": [{"contributor": "/s/resource/wikt...
# 19941023   "sources": [{"contributor": "/s/resource/wikt...
# 19941024   "sources": [{"contributor": "/s/resource/wikt...
#
#                                           process           weight
# 16193396   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941017   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941018   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941019   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941020   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941021   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941022   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941023   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}
# 19941024   "process": "/s/process/wikiparsec/2"}]   "weight": 1.0}

# %%
df_co[df_co["subject"] == "/c/en/piano/"]["object"].iloc[37]
# Out:
# '/c/en/instrument_of_music/]\t/r/IsA\t/c/en/piano\t/c/en/instrument_of_music\t{"dataset": "/d/conceptnet/4/en"'

# %%
df_co[df_co["subject"] == "/c/en/piano/"]
# Out:
#                                    relation       subject  \
# 84765                    /a/[/r/AtLocation/  /c/en/piano/
# 84766                    /a/[/r/AtLocation/  /c/en/piano/
# 84767                    /a/[/r/AtLocation/  /c/en/piano/
# 84768                    /a/[/r/AtLocation/  /c/en/piano/
# 84769                    /a/[/r/AtLocation/  /c/en/piano/
# 84770                    /a/[/r/AtLocation/  /c/en/piano/
# 84771                    /a/[/r/AtLocation/  /c/en/piano/
# 84772                    /a/[/r/AtLocation/  /c/en/piano/
# 84773                    /a/[/r/AtLocation/  /c/en/piano/
# 84774                    /a/[/r/AtLocation/  /c/en/piano/
# 84775                    /a/[/r/AtLocation/  /c/en/piano/
# 84776                    /a/[/r/AtLocation/  /c/en/piano/
# 84777                    /a/[/r/AtLocation/  /c/en/piano/
# 84778                    /a/[/r/AtLocation/  /c/en/piano/
# 190847                    /a/[/r/CapableOf/  /c/en/piano/
# 345811                    /a/[/r/DefinedAs/  /c/en/piano/
# 775993                  /a/[/r/DerivedFrom/  /c/en/piano/
# 1563729   /a/[/r/EtymologicallyDerivedFrom/  /c/en/piano/
# 1951447     /a/[/r/EtymologicallyRelatedTo/  /c/en/piano/
# 1951448     /a/[/r/EtymologicallyRelatedTo/  /c/en/piano/
# 1951449     /a/[/r/EtymologicallyRelatedTo/  /c/en/piano/
# 4148205                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148206                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148207                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148208                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148209                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148210                 /a/[/r/ExternalURL/  /c/en/piano/
# 4148211                 /a/[/r/ExternalURL/  /c/en/piano/
# 15955591                       /a/[/r/HasA/  /c/en/piano/
# 15955592                       /a/[/r/HasA/  /c/en/piano/
# ...                                     ...           ...
# 19941001                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941002                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941003                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941004                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941005                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941006                  /a/[/r/RelatedTo/  /c/en/piano/
# 19941007                  /a/[/r/RelatedTo/  /c/en/piano/
# 29309531                    /a/[/r/Synonym/  /c/en/piano/
# 34008214                    /a/[/r/UsedFor/  /c/en/piano/
# 34008215                    /a/[/r/UsedFor/  /c/en/piano/
# 34008216                    /a/[/r/UsedFor/  /c/en/piano/
# 34008217                    /a/[/r/UsedFor/  /c/en/piano/
# 34008218                    /a/[/r/UsedFor/  /c/en/piano/
# 34008219                    /a/[/r/UsedFor/  /c/en/piano/
# 34008220                    /a/[/r/UsedFor/  /c/en/piano/
# 34008221                    /a/[/r/UsedFor/  /c/en/piano/
# 34008222                    /a/[/r/UsedFor/  /c/en/piano/
# 34008223                    /a/[/r/UsedFor/  /c/en/piano/
# 34008224                    /a/[/r/UsedFor/  /c/en/piano/
# 34008225                    /a/[/r/UsedFor/  /c/en/piano/
# 34008226                    /a/[/r/UsedFor/  /c/en/piano/
# 34008227                    /a/[/r/UsedFor/  /c/en/piano/
# 34008228                    /a/[/r/UsedFor/  /c/en/piano/
# 34008229                    /a/[/r/UsedFor/  /c/en/piano/
# 34008230                    /a/[/r/UsedFor/  /c/en/piano/
# 34008231                    /a/[/r/UsedFor/  /c/en/piano/
# 34008232                    /a/[/r/UsedFor/  /c/en/piano/
# 34008233                    /a/[/r/UsedFor/  /c/en/piano/
# 34008234                    /a/[/r/UsedFor/  /c/en/piano/
# 34072999           /a/[/r/dbpedia/language/  /c/en/piano/
#
#                                                      object  \
# 84765     /c/en/church/]\t/r/AtLocation\t/c/en/piano\t/c...
# 84766     /c/en/concert/]\t/r/AtLocation\t/c/en/piano\t/...
# 84767     /c/en/concert_hall/]\t/r/AtLocation\t/c/en/pia...
# 84768     /c/en/drawing_room/]\t/r/AtLocation\t/c/en/pia...
# 84769     /c/en/music_room/]\t/r/AtLocation\t/c/en/piano...
# 84770     /c/en/music_school/]\t/r/AtLocation\t/c/en/pia...
# 84771     /c/en/music_store/]\t/r/AtLocation\t/c/en/pian...
# 84772     /c/en/neighbor's_house/]\t/r/AtLocation\t/c/en...
# 84773     /c/en/old_movie/]\t/r/AtLocation\t/c/en/piano\...
# 84774     /c/en/orchestra/]\t/r/AtLocation\t/c/en/piano\...
# 84775     /c/en/restaurant/]\t/r/AtLocation\t/c/en/piano...
# 84776     /c/en/store_or_home/]\t/r/AtLocation\t/c/en/pi...
# 84777     /c/en/symphony/]\t/r/AtLocation\t/c/en/piano\t...
# 84778     /c/en/symphony_orchestra/]\t/r/AtLocation\t/c/...
# 190847    /c/en/sound_out_of_tune/]\t/r/CapableOf\t/c/en...
# 345811    /c/en/heart_of_modern_jazz_group/]\t/r/Defined...
# 775993    /c/en/pianoforte/n/]\t/r/DerivedFrom\t/c/en/pi...
# 1563729   /c/it/pianoforte/]\t/r/EtymologicallyDerivedFr...
# 1951447   /c/en/pianoforte/]\t/r/EtymologicallyRelatedTo...
# 1951448   /c/it/forte/]\t/r/EtymologicallyRelatedTo\t/c/...
# 1951449   /c/it/piano/]\t/r/EtymologicallyRelatedTo\t/c/...
# 4148205   /http://dbpedia.org/resource/Piano/]\t/r/Exter...
# 4148206   /http://dbpedia.org/resource/The_Piano/]\t/r/E...
# 4148207   /http://en.wiktionary.org/wiki/piano/]\t/r/Ext...
# 4148208   /http://fr.wiktionary.org/wiki/piano/]\t/r/Ext...
# 4148209   /http://umbel.org/umbel/sc/Piano_Acoustic/]\t/...
# 4148210   /http://wikidata.dbpedia.org/resource/Q117315/...
# 4148211   /http://wikidata.dbpedia.org/resource/Q5994/]\...
# 15955591  /c/en/88_black_and_white_keys/]\t/r/HasA\t/c/e...
# 15955592  /c/en/88_keys/]\t/r/HasA\t/c/en/piano\t/c/en/8...
# ...                                                     ...
# 19941001  /c/en/notes/]\t/r/RelatedTo\t/c/en/piano\t/c/e...
# 19941002  /c/en/orchestra/]\t/r/RelatedTo\t/c/en/piano\t...
# 19941003  /c/en/pedals/]\t/r/RelatedTo\t/c/en/piano\t/c/...
# 19941004  /c/en/rooms/]\t/r/RelatedTo\t/c/en/piano\t/c/e...
# 19941005  /c/en/stringed/]\t/r/RelatedTo\t/c/en/piano\t/...
# 19941006  /c/en/white/]\t/r/RelatedTo\t/c/en/piano\t/c/e...
# 19941007  /c/en/white_notes/]\t/r/RelatedTo\t/c/en/piano...
# 29309531  /c/en/piano/]\t/r/Synonym\t/c/en/piano\t/c/en/...
# 34008214  /c/en/accompany_orchestra/]\t/r/UsedFor\t/c/en...
# 34008215  /c/en/accompanying_orchestra/]\t/r/UsedFor\t/c...
# 34008216  /c/en/create_mucic/]\t/r/UsedFor\t/c/en/piano\...
# 34008217  /c/en/create_music/]\t/r/UsedFor\t/c/en/piano\...
# 34008218  /c/en/creating_piano_music/]\t/r/UsedFor\t/c/e...
# 34008219  /c/en/decorating_home/]\t/r/UsedFor\t/c/en/pia...
# 34008220  /c/en/decoration/]\t/r/UsedFor\t/c/en/piano\t/...
# 34008221  /c/en/entertainment/]\t/r/UsedFor\t/c/en/piano...
# 34008222  /c/en/listening/]\t/r/UsedFor\t/c/en/piano\t/c...
# 34008223  /c/en/making_beautiful_sounds/]\t/r/UsedFor\t/...
# 34008224  /c/en/music/]\t/r/UsedFor\t/c/en/piano\t/c/en/...
# 34008225  /c/en/percussing_string_sounds/]\t/r/UsedFor\t...
# 34008226  /c/en/perform_music/]\t/r/UsedFor\t/c/en/piano...
# 34008227  /c/en/performing_concertos/]\t/r/UsedFor\t/c/e...
# 34008228  /c/en/performing_music/]\t/r/UsedFor\t/c/en/pi...
# 34008229  /c/en/play_rag/]\t/r/UsedFor\t/c/en/piano\t/c/...
# 34008230  /c/en/playing/]\t/r/UsedFor\t/c/en/piano\t/c/e...
# 34008231  /c/en/playing_beehthoven_scores/]\t/r/UsedFor\...
# 34008232  /c/en/providing_employement_for_piano_key_tune...
# 34008233  /c/en/teaching/]\t/r/UsedFor\t/c/en/piano\t/c/...
# 34008234  /c/en/teaching_children_to_play_music/]\t/r/Us...
# 34072999  /c/en/british_sign_language/]\t/r/dbpedia/lang...
#
#                              license  \
# 84765         "license": "cc:by/4.0"
# 84766         "license": "cc:by/4.0"
# 84767         "license": "cc:by/4.0"
# 84768         "license": "cc:by/4.0"
# 84769         "license": "cc:by/4.0"
# 84770         "license": "cc:by/4.0"
# 84771         "license": "cc:by/4.0"
# 84772         "license": "cc:by/4.0"
# 84773         "license": "cc:by/4.0"
# 84774         "license": "cc:by/4.0"
# 84775         "license": "cc:by/4.0"
# 84776         "license": "cc:by/4.0"
# 84777         "license": "cc:by/4.0"
# 84778         "license": "cc:by/4.0"
# 190847        "license": "cc:by/4.0"
# 345811        "license": "cc:by/4.0"
# 775993     "license": "cc:by-sa/4.0"
# 1563729    "license": "cc:by-sa/4.0"
# 1951447    "license": "cc:by-sa/4.0"
# 1951448    "license": "cc:by-sa/4.0"
# 1951449    "license": "cc:by-sa/4.0"
# 4148205    "license": "cc:by-sa/4.0"
# 4148206    "license": "cc:by-sa/4.0"
# 4148207    "license": "cc:by-sa/4.0"
# 4148208    "license": "cc:by-sa/4.0"
# 4148209       "license": "cc:by/4.0"
# 4148210    "license": "cc:by-sa/4.0"
# 4148211    "license": "cc:by-sa/4.0"
# 15955591      "license": "cc:by/4.0"
# 15955592      "license": "cc:by/4.0"
# ...                              ...
# 19941001      "license": "cc:by/4.0"
# 19941002      "license": "cc:by/4.0"
# 19941003      "license": "cc:by/4.0"
# 19941004      "license": "cc:by/4.0"
# 19941005      "license": "cc:by/4.0"
# 19941006      "license": "cc:by/4.0"
# 19941007      "license": "cc:by/4.0"
# 29309531   "license": "cc:by-sa/4.0"
# 34008214      "license": "cc:by/4.0"
# 34008215      "license": "cc:by/4.0"
# 34008216      "license": "cc:by/4.0"
# 34008217      "license": "cc:by/4.0"
# 34008218      "license": "cc:by/4.0"
# 34008219      "license": "cc:by/4.0"
# 34008220      "license": "cc:by/4.0"
# 34008221      "license": "cc:by/4.0"
# 34008222      "license": "cc:by/4.0"
# 34008223      "license": "cc:by/4.0"
# 34008224      "license": "cc:by/4.0"
# 34008225      "license": "cc:by/4.0"
# 34008226      "license": "cc:by/4.0"
# 34008227      "license": "cc:by/4.0"
# 34008228      "license": "cc:by/4.0"
# 34008229      "license": "cc:by/4.0"
# 34008230      "license": "cc:by/4.0"
# 34008231      "license": "cc:by/4.0"
# 34008232      "license": "cc:by/4.0"
# 34008233      "license": "cc:by/4.0"
# 34008234      "license": "cc:by/4.0"
# 34072999   "license": "cc:by-sa/4.0"
#
#                                                      source  \
# 84765      "sources": [{"activity": "/s/activity/omcs/om...
# 84766      "sources": [{"activity": "/s/activity/omcs/om...
# 84767      "sources": [{"activity": "/s/activity/omcs/om...
# 84768      "sources": [{"activity": "/s/activity/omcs/om...
# 84769      "sources": [{"activity": "/s/activity/omcs/om...
# 84770      "sources": [{"activity": "/s/activity/omcs/co...
# 84771      "sources": [{"activity": "/s/activity/omcs/om...
# 84772      "sources": [{"activity": "/s/activity/omcs/om...
# 84773      "sources": [{"activity": "/s/activity/omcs/om...
# 84774      "sources": [{"activity": "/s/activity/omcs/om...
# 84775      "sources": [{"activity": "/s/activity/omcs/te...
# 84776      "sources": [{"activity": "/s/activity/omcs/om...
# 84777      "sources": [{"activity": "/s/activity/omcs/co...
# 84778      "sources": [{"activity": "/s/activity/omcs/om...
# 190847     "sources": [{"activity": "/s/activity/omcs/om...
# 345811     "sources": [{"activity": "/s/activity/omcs/om...
# 775993     "sources": [{"contributor": "/s/resource/wikt...
# 1563729    "sources": [{"contributor": "/s/resource/wikt...
# 1951447    "sources": [{"contributor": "/s/resource/wikt...
# 1951448    "sources": [{"contributor": "/s/resource/wikt...
# 1951449    "sources": [{"contributor": "/s/resource/wikt...
# 4148205    "sources": [{"contributor": "/s/resource/dbpe...
# 4148206    "sources": [{"contributor": "/s/resource/dbpe...
# 4148207    "sources": [{"contributor": "/s/resource/wikt...
# 4148208    "sources": [{"contributor": "/s/resource/wikt...
# 4148209    "sources": [{"contributor": "/s/resource/open...
# 4148210    "sources": [{"contributor": "/s/resource/dbpe...
# 4148211    "sources": [{"contributor": "/s/resource/dbpe...
# 15955591   "sources": [{"activity": "/s/activity/omcs/om...
# 15955592   "sources": [{"activity": "/s/activity/omcs/om...
# ...                                                     ...
# 19941001   "sources": [{"contributor": "/s/resource/verb...
# 19941002   "sources": [{"contributor": "/s/resource/verb...
# 19941003   "sources": [{"contributor": "/s/resource/verb...
# 19941004   "sources": [{"contributor": "/s/resource/verb...
# 19941005   "sources": [{"contributor": "/s/resource/verb...
# 19941006   "sources": [{"contributor": "/s/resource/verb...
# 19941007   "sources": [{"contributor": "/s/resource/verb...
# 29309531   "sources": [{"contributor": "/s/resource/dbpe...
# 34008214   "sources": [{"activity": "/s/activity/omcs/om...
# 34008215   "sources": [{"activity": "/s/activity/omcs/om...
# 34008216   "sources": [{"activity": "/s/activity/omcs/om...
# 34008217   "sources": [{"activity": "/s/activity/omcs/om...
# 34008218   "sources": [{"activity": "/s/activity/omcs/om...
# 34008219   "sources": [{"activity": "/s/activity/omcs/om...
# 34008220   "sources": [{"activity": "/s/activity/omcs/om...
# 34008221   "sources": [{"activity": "/s/activity/omcs/om...
# 34008222   "sources": [{"activity": "/s/activity/omcs/om...
# 34008223   "sources": [{"activity": "/s/activity/omcs/om...
# 34008224   "sources": [{"activity": "/s/activity/omcs/co...
# 34008225   "sources": [{"activity": "/s/activity/omcs/om...
# 34008226   "sources": [{"activity": "/s/activity/omcs/te...
# 34008227   "sources": [{"activity": "/s/activity/omcs/om...
# 34008228   "sources": [{"activity": "/s/activity/omcs/om...
# 34008229   "sources": [{"activity": "/s/activity/omcs/te...
# 34008230   "sources": [{"activity": "/s/activity/omcs/om...
# 34008231   "sources": [{"activity": "/s/activity/omcs/om...
# 34008232   "sources": [{"activity": "/s/activity/omcs/om...
# 34008233   "sources": [{"activity": "/s/activity/omcs/om...
# 34008234   "sources": [{"activity": "/s/activity/omcs/om...
# 34072999   "sources": [{"contributor": "/s/resource/dbpe...
#
#                                                     process  \
# 84765         "contributor": "/s/contributor/omcs/rcarey1"}
# 84766       "contributor": "/s/contributor/omcs/lennonkbc"}
# 84767      "contributor": "/s/contributor/omcs/nihilmatt...
# 84768          "contributor": "/s/contributor/omcs/rod57"}]
# 84769      "contributor": "/s/contributor/omcs/meowmille...
# 84770       "contributor": "/s/contributor/omcs/maofnoah"}]
# 84771         "contributor": "/s/contributor/omcs/bedume"}]
# 84772        "contributor": "/s/contributor/omcs/annedog"}]
# 84773        "contributor": "/s/contributor/omcs/annedog"}]
# 84774             "contributor": "/s/contributor/omcs/bjb"}
# 84775        "contributor": "/s/contributor/omcs/anaitis"}]
# 84776       "contributor": "/s/contributor/omcs/brainiac"}]
# 84777         "contributor": "/s/contributor/omcs/lieber"}]
# 84778          "contributor": "/s/contributor/omcs/duana"}]
# 190847     "contributor": "/s/contributor/omcs/annieroon...
# 345811      "contributor": "/s/contributor/omcs/laserjoy"}]
# 775993               "process": "/s/process/wikiparsec/2"}]
# 1563729              "process": "/s/process/wikiparsec/2"}]
# 1951447              "process": "/s/process/wikiparsec/2"}]
# 1951448              "process": "/s/process/wikiparsec/2"}]
# 1951449              "process": "/s/process/wikiparsec/2"}]
# 4148205                                      "weight": 1.0}
# 4148206                                      "weight": 1.0}
# 4148207              "process": "/s/process/wikiparsec/2"}]
# 4148208              "process": "/s/process/wikiparsec/2"}]
# 4148209                                      "weight": 1.0}
# 4148210                                      "weight": 1.0}
# 4148211                                      "weight": 1.0}
# 15955591    "contributor": "/s/contributor/omcs/moreland"}]
# 15955592    "contributor": "/s/contributor/omcs/mjcarrier"}
# ...                                                     ...
# 19941001              "process": "/s/process/split_words"}]
# 19941002                          "surfaceEnd": "orchestra"
# 19941003              "process": "/s/process/split_words"}]
# 19941004              "process": "/s/process/split_words"}]
# 19941005                           "surfaceEnd": "stringed"
# 19941006              "process": "/s/process/split_words"}]
# 19941007                        "surfaceEnd": "white notes"
# 29309531                                     "weight": 1.0}
# 34008214    "contributor": "/s/contributor/omcs/phraughy"}]
# 34008215     "contributor": "/s/contributor/omcs/laserjoy"}
# 34008216     "contributor": "/s/contributor/omcs/annedog"}]
# 34008217        "contributor": "/s/contributor/omcs/dbn3"}]
# 34008218    "contributor": "/s/contributor/omcs/laserjoy"}]
# 34008219    "contributor": "/s/contributor/omcs/laserjoy"}]
# 34008220        "contributor": "/s/contributor/omcs/json"}]
# 34008221        "contributor": "/s/contributor/omcs/json"}]
# 34008222        "contributor": "/s/contributor/omcs/json"}]
# 34008223      "contributor": "/s/contributor/omcs/cerewa"}]
# 34008224    "contributor": "/s/contributor/omcs/triplitex"}
# 34008225    "contributor": "/s/contributor/omcs/laserjoy"}]
# 34008226     "contributor": "/s/contributor/omcs/avenger"}]
# 34008227      "contributor": "/s/contributor/omcs/cerewa"}]
# 34008228       "contributor": "/s/contributor/omcs/arnaud"}
# 34008229        "contributor": "/s/contributor/omcs/dbn3"}]
# 34008230        "contributor": "/s/contributor/omcs/json"}]
# 34008231    "contributor": "/s/contributor/omcs/shaleane"}]
# 34008232    "contributor": "/s/contributor/omcs/shaleane"}]
# 34008233        "contributor": "/s/contributor/omcs/json"}]
# 34008234     "contributor": "/s/contributor/omcs/annedog"}]
# 34072999                                     "weight": 0.5}
#
#                                                      weight
# 84765                  {"activity": "/s/activity/omcs/vote"
# 84766      {"activity": "/s/activity/omcs/omcs1_possibly...
# 84767      {"activity": "/s/activity/omcs/omcs1_possibly...
# 84768                      "surfaceEnd": "the drawing room"
# 84769                        "surfaceEnd": "the music room"
# 84770                       "surfaceEnd": "...music school"
# 84771                         "surfaceEnd": "a music store"
# 84772                    "surfaceEnd": "a neighbor's house"
# 84773                          "surfaceEnd": "an old movie"
# 84774                  {"activity": "/s/activity/omcs/vote"
# 84775                          "surfaceEnd": "a restaurant"
# 84776                      "surfaceEnd": "a store or a home
# 84777                            "surfaceEnd": "a symphony"
# 84778                    "surfaceEnd": "symphony orchestra"
# 190847                    "surfaceEnd": "sound out of tune"
# 345811         "surfaceEnd": "heart of a modern jazz group"
# 775993                                       "weight": 1.0}
# 1563729                                      "weight": 1.0}
# 1951447                                     "weight": 0.25}
# 1951448                                     "weight": 0.25}
# 1951449                                     "weight": 0.25}
# 4148205                                                 NaN
# 4148206                                                 NaN
# 4148207                                     "weight": 0.25}
# 4148208                                     "weight": 0.25}
# 4148209                                                 NaN
# 4148210                                                 NaN
# 4148211                                                 NaN
# 15955591            "surfaceEnd": "88 black and white keys"
# 15955592               {"activity": "/s/activity/omcs/vote"
# ...                                                     ...
# 19941001                              "surfaceEnd": "notes"
# 19941002                            "surfaceStart": "piano"
# 19941003                             "surfaceEnd": "pedals"
# 19941004                              "surfaceEnd": "rooms"
# 19941005                            "surfaceStart": "piano"
# 19941006                              "surfaceEnd": "white"
# 19941007                            "surfaceStart": "piano"
# 29309531                                                NaN
# 34008214             "surfaceEnd": "accompany an orchestra"
# 34008215               {"activity": "/s/activity/omcs/vote"
# 34008216                       "surfaceEnd": "create mucic"
# 34008217                       "surfaceEnd": "create music"
# 34008218               "surfaceEnd": "creating piano music"
# 34008219                  "surfaceEnd": "decorating a home"
# 34008220                         "surfaceEnd": "decoration"
# 34008221                      "surfaceEnd": "entertainment"
# 34008222                          "surfaceEnd": "listening"
# 34008223            "surfaceEnd": "making beautiful sounds"
# 34008224   {"activity": "/s/activity/omcs/omcs1_possibly...
# 34008225           "surfaceEnd": "percussing string sounds"
# 34008226                      "surfaceEnd": "perform music"
# 34008227               "surfaceEnd": "performing concertos"
# 34008228               {"activity": "/s/activity/omcs/vote"
# 34008229                         "surfaceEnd": "play a rag"
# 34008230                            "surfaceEnd": "playing"
# 34008231          "surfaceEnd": "playing Beehthoven scores"
# 34008232   "surfaceEnd": "providing employement for pian...
# 34008233                           "surfaceEnd": "teaching"
# 34008234    "surfaceEnd": "teaching children to play music"
# 34072999                                                NaN
#
# [107 rows x 7 columns]

# %%
df_co[df_co["subject"] == "/c/ko/피아노/"]
# Out:
#                                  relation     subject  \
# 2155975   /a/[/r/EtymologicallyRelatedTo/  /c/ko/피아노/
# 8731825               /a/[/r/ExternalURL/  /c/ko/피아노/
# 8731826               /a/[/r/ExternalURL/  /c/ko/피아노/
# 8731827               /a/[/r/ExternalURL/  /c/ko/피아노/
# 32496008                  /a/[/r/Synonym/  /c/ko/피아노/
#
#                                                      object  \
# 2155975   /c/en/piano/]\t/r/EtymologicallyRelatedTo\t/c/...
# 8731825   /http://en.wiktionary.org/wiki/피아노/]\t/r/Exter...
# 8731826   /http://fr.wiktionary.org/wiki/피아노/]\t/r/Exter...
# 8731827   /http://ko.dbpedia.org/resource/피아노/]\t/r/Exte...
# 32496008  /c/en/piano/]\t/r/Synonym\t/c/ko/피아노\t/c/en/pi...
#
#                              license  \
# 2155975    "license": "cc:by-sa/4.0"
# 8731825    "license": "cc:by-sa/4.0"
# 8731826    "license": "cc:by-sa/4.0"
# 8731827    "license": "cc:by-sa/4.0"
# 32496008   "license": "cc:by-sa/4.0"
#
#                                                      source  \
# 2155975    "sources": [{"contributor": "/s/resource/wikt...
# 8731825    "sources": [{"contributor": "/s/resource/wikt...
# 8731826    "sources": [{"contributor": "/s/resource/wikt...
# 8731827    "sources": [{"contributor": "/s/resource/dbpe...
# 32496008   "sources": [{"contributor": "/s/resource/dbpe...
#
#                                           process            weight
# 2155975    "process": "/s/process/wikiparsec/2"}]   "weight": 0.25}
# 8731825    "process": "/s/process/wikiparsec/2"}]   "weight": 0.25}
# 8731826    "process": "/s/process/wikiparsec/2"}]   "weight": 0.25}
# 8731827                            "weight": 1.0}               NaN
# 32496008                           "weight": 0.5}               NaN

# %%
df_co[df_co["subject"] == "/c/ko/피아노/r"]
# Out:
# Empty DataFrame
# Columns: [relation, subject, object, license, source, process, weight]
# Index: []
